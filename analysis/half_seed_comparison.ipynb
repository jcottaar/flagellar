# %%
import sys
sys.path.append('d:/flagellar/code/core')
sys.path.append('/kaggle/code/core')
sys.path.append('/kaggle/input/my-flg-library/')
import flg_support as fls
import importlib
import numpy as np
import flg_diagnostics
import flg_numerics
import matplotlib.pyplot as plt
importlib.reload(fls);
fls.profiling=False
sz = 5
sx = 200
sy = 200
t = 8
# Out:
# MainProcess
# MainProcess

# %%
half1 = [0.323, 0.349, 0.325, 0.372, 0.325]
half2 = [0.425, 0.426, 0.418, 0.438, 0.438]
plt.scatter(half1,half2)
