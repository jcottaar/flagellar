# %%
import kagglehub
import os
os.environ['KAGGLEHUB_CACHE'] = '/flagellar/cache/'
import sys
sys.path.append('d:/flagellar/code/core')
sys.path.append('/flagellar/code/core/')
sys.path.append('/kaggle/input/my-flg-library/')
import flg_support as fls

# %%
kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py")
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py/versions/5/*.h5 /flagellar/cache/
# Out:
# ...
#   0%|          | 184M/129G [00:07<1:34:39, 24.4MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py")
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/datasets.py:35, in dataset_download(handle, path, force_download)
#      33 h = parse_dataset_handle(handle)
#      34 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 35 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      36 return path
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
# ...

# %%
kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py-part-2")
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py-part-2/versions/6/*.h5 /flagellar/cache/
# Out:
# ...
#   0%|          | 184M/129G [00:07<1:34:39, 24.4MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py")
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/datasets.py:35, in dataset_download(handle, path, force_download)
#      33 h = parse_dataset_handle(handle)
#      34 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 35 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      36 return path
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
# ...

# %%
kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py-part-3")
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py-part-3/versions/XXX/*.h5 /flagellar/cache/
# Out:
# ...
#   0%|          | 184M/129G [00:07<1:34:39, 24.4MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py")
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/datasets.py:35, in dataset_download(handle, path, force_download)
#      33 h = parse_dataset_handle(handle)
#      34 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 35 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      36 return path
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
# ...

# %%
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py/versions/5/*.h5 /flagellar/cache/
# Out:
# Signature:
# kagglehub.dataset_download(
#     handle: str,
#     path: Optional[str] = None,
#     *,
#     force_download: Optional[bool] = False,
# ) -> str
# Docstring:
# Download dataset files
# Args:
#     handle: (string) the dataset handle
#     path: (string) Optional path to a file within a dataset
#     force_download: (bool) Optional flag to force download a dataset, even if it's cached
# Returns:
#     A string requesting the path to the requested dataset files.
# File:      c:\users\jeroe\anaconda3\envs\jupyterlab-debugger2\lib\site-packages\kagglehub\datasets.py
# Type:      function

# %%
names = fls.dill_load('/flagellar/code/names_set_2.pickle')
for n in names:
    print(n)
    if os.path.isfile('/flagellar/cache/'+n+'.h5'):
        continue
    while True:
        try:
            kagglehub.dataset_download("jeroencottaar/byu-flagellar-motors-as-h5py-part-2", path=n +'.h5')
            break
        except Exception as e:
            print(e)
# Out:
# tomo_a020d7
# tomo_a0cb00
# tomo_a1a9a3
# tomo_a2a928
# tomo_a2bf30
# tomo_a37a5c
# tomo_a3ed10
# tomo_a46b26
# tomo_a4c52f
# tomo_a4f419
# tomo_a537dd
# tomo_a549d6
# tomo_a5ac23
# tomo_a6646f
# tomo_a67e9f
# tomo_a72a52
# tomo_a75c98
# tomo_a8073d
# tomo_a81e01
# tomo_a84050
# tomo_a8bf76
# tomo_a910fe
# tomo_a9d067
# tomo_aaa1fd
# tomo_ab30af
# tomo_ab78d0
# tomo_ab804d
# tomo_abac2e
# tomo_abb45a
# tomo_abbd3b
# tomo_ac4f0d
# tomo_ac9fef
# tomo_acadd7
# tomo_adc026
# tomo_ae347a
# tomo_aeaf51
# tomo_aec312
# tomo_aff073
# tomo_b03f81
# tomo_b0ded6
# tomo_b0e5c6
# tomo_b10aa4
# tomo_b11ddc
# tomo_b18127
# tomo_b24f1a
# tomo_b28579
# tomo_b2b342
# tomo_b2eb0c
# tomo_b2ebbc
# tomo_b33d4e
# tomo_b4a1f0
# tomo_b4d92b
# tomo_b4d9da
# tomo_b50c0f
# tomo_b54396
# tomo_b7becf
# tomo_b7d014
# tomo_b7d94c
# tomo_b80310
# tomo_b8595d
# tomo_b87c8e
# tomo_b8f096
# tomo_b9088c
# tomo_b93a2d
# tomo_b98cf6
# tomo_b9de3e
# tomo_b9eb9a
# tomo_ba37ec
# tomo_ba76d8
# tomo_ba9b3d
# tomo_bad724
# ...

# %%
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py-part-2/versions/5/*.h5 /flagellar/cache/
# !mv /flagellar/cache/datasets/jeroencottaar/byu-flagellar-motors-as-h5py-part-2/versions/5/*.csv /flagellar/data/
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
kagglehub.dataset_download('bricevergnou/spotify-recommendation', path='data.csv')
# Out:
# ...
# 100%|██████████| 14.0k/14.0k [00:00<00:00, 11.2MB/s]
# '/flagellar/cache/datasets/bricevergnou/spotify-recommendation/versions/2/data.csv'
